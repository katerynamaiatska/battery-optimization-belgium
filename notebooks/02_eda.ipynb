# %% [markdown]
# # 02 — Exploratory Data Analysis
#
# Goals:
# - Understand the structure and quality of the collected data
# - Explore price seasonality and extreme events (negative prices, spikes)
# - Explore household consumption patterns
# - Understand correlation between weather and price/consumption

# %% [markdown]
# ## 0. Imports & data loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df_prices  = pd.read_csv('../Data/prices_be.csv', parse_dates=['timestamp'])
df_weather = pd.read_csv('../Data/weather_antwerp.csv', parse_dates=['date']).rename(columns={'date': 'timestamp'})
df_load  = pd.read_csv('../Data/load_profile.csv', parse_dates=['timestamp'])  # add when available

print(df_prices.shape, df_weather.shape, df_load.shape)
print(df_prices.dtypes)
print(df_weather.dtypes)
print(df_load.dtypes)

# %% [markdown]
# ## 1. Price data — quality check

# %%
print(df_prices.describe())
print('\nMissing values:', df_prices.isnull().sum().to_dict())
print('Negative prices:', (df_prices['price_eur_kwh'] < 0).sum())

# %% [markdown]
# ## 2. Price seasonality

# %%
df_prices['year']  = df_prices['timestamp'].dt.year
df_prices['month'] = df_prices['timestamp'].dt.month
df_prices['hour']  = df_prices['timestamp'].dt.hour

fig, axes = plt.subplots(1, 2, figsize=(14, 4))

df_prices.groupby('month')['price_eur_kwh'].mean().plot(ax=axes[0], marker='o')
axes[0].set_title('Average price by month')
axes[0].set_xlabel('Month')
axes[0].set_ylabel('EUR/kWh')

df_prices.groupby('hour')['price_eur_kwh'].mean().plot(ax=axes[1], marker='o', color='orange')
axes[1].set_title('Average price by hour of day')
axes[1].set_xlabel('Hour')
axes[1].set_ylabel('EUR/kWh')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Weather data — quality check

# %%
print(df_weather.describe())
print('\nMissing values:', df_weather.isnull().sum().to_dict())

# %% [markdown]
# ## 4. Household consumption (placeholder)
#
# > **TODO:** Add analysis when load profile data is provided by mentor.
